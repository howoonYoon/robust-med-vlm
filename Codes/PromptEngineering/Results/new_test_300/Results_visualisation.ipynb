# %% [markdown]
# # 0) Clean image performance

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

files = {
    "internvl": "internvl_clean_baseline.csv",
    "lingshu": "lingshu_clean_baseline.csv",
    "medgemma": "medgemma_clean_baseline.csv",
    "qwen3": "qwen3_clean_baseline.csv",
}

modalities = ["MRI", "OCT", "Xray"]

results = []

for model, path in files.items():
    df = pd.read_csv(path)

    # 타입 정리 (문자열/공백/NaN 방지)
    df["gt_binary"] = pd.to_numeric(df["gt_binary"], errors="coerce")
    df["pred_binary"] = pd.to_numeric(df["pred_binary"], errors="coerce")
    df["is_correct"] = pd.to_numeric(df["is_correct"], errors="coerce")

    for mod in modalities:
        sub = df[df["dataset"] == mod].copy()
        if sub.empty:
            continue

        # label이 NaN인 행 제거
        sub = sub.dropna(subset=["gt_binary", "pred_binary"])
        y_true = sub["gt_binary"].astype(int)
        y_pred = sub["pred_binary"].astype(int)

        results.append({
            "model": model,
            "dataset": mod,
            "n_samples": len(sub),
            "accuracy": accuracy_score(y_true, y_pred),
            "precision": precision_score(y_true, y_pred, zero_division=0),
            "recall": recall_score(y_true, y_pred, zero_division=0),
            "f1": f1_score(y_true, y_pred, zero_division=0),
            # sanity check: is_correct가 제대로면 아래 두 값이 같아야 함
            "is_correct_mean": sub["is_correct"].mean(),
        })

results_df = pd.DataFrame(results)

pivot = (
    results_df
    .pivot_table(
        index=["model", "dataset"],
        values=["n_samples", "accuracy", "precision", "recall", "f1"],
    )
    .sort_index()
)

pivot = pivot[["n_samples", "accuracy", "precision", "recall", "f1"]]
#print(pivot.round(4))

from IPython.display import display

metrics = ["n_samples", "accuracy", "precision", "recall", "f1"]
dataset_order = ["MRI", "OCT", "Xray"]

for model in results_df["model"].unique():
    print(f"\n🤖 {model.upper()} — Clean baseline")

    tbl = (
        results_df[results_df["model"] == model]
        .set_index("dataset")[metrics]
        .reindex(dataset_order)
    )

    display(
        tbl.style
        .format({
            "accuracy":"{:.4f}",
            "precision":"{:.4f}",
            "recall":"{:.4f}",
            "f1":"{:.4f}",
            "n_samples":"{:.0f}",
        })
        .background_gradient(subset=["f1"])
    )
# Out:
# 🤖 INTERNVL — Clean baseline
# <style type="text/css">
# #T_27283_row0_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_27283_row1_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_27283_row2_col4 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_27283">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27283_level0_col0" class="col_heading level0 col0" >n_samples</th>
#       <th id="T_27283_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_27283_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_27283_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_27283_level0_col4" class="col_heading level0 col4" >f1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27283_level0_row0" class="row_heading level0 row0" >MRI</th>
#       <td id="T_27283_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_27283_row0_col1" class="data row0 col1" >0.8000</td>
#       <td id="T_27283_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_27283_row0_col3" class="data row0 col3" >0.6000</td>
#       <td id="T_27283_row0_col4" class="data row0 col4" >0.7500</td>
#     </tr>
#     <tr>
#       <th id="T_27283_level0_row1" class="row_heading level0 row1" >OCT</th>
#       <td id="T_27283_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_27283_row1_col1" class="data row1 col1" >0.7000</td>
#       <td id="T_27283_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_27283_row1_col3" class="data row1 col3" >0.4000</td>
#       <td id="T_27283_row1_col4" class="data row1 col4" >0.5714</td>
#     </tr>
#     <tr>
#       <th id="T_27283_level0_row2" class="row_heading level0 row2" >Xray</th>
#       <td id="T_27283_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_27283_row2_col1" class="data row2 col1" >0.7500</td>
#       <td id="T_27283_row2_col2" class="data row2 col2" >0.8571</td>
#       <td id="T_27283_row2_col3" class="data row2 col3" >0.6000</td>
#       <td id="T_27283_row2_col4" class="data row2 col4" >0.7059</td>
#     </tr>
#   </tbody>
# </table>
# 🤖 LINGSHU — Clean baseline
# <style type="text/css">
# #T_c33ec_row0_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c33ec_row1_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c33ec_row2_col4 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c33ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c33ec_level0_col0" class="col_heading level0 col0" >n_samples</th>
#       <th id="T_c33ec_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_c33ec_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_c33ec_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_c33ec_level0_col4" class="col_heading level0 col4" >f1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c33ec_level0_row0" class="row_heading level0 row0" >MRI</th>
#       <td id="T_c33ec_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_c33ec_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_c33ec_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_c33ec_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_c33ec_row0_col4" class="data row0 col4" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c33ec_level0_row1" class="row_heading level0 row1" >OCT</th>
#       <td id="T_c33ec_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_c33ec_row1_col1" class="data row1 col1" >0.7000</td>
#       <td id="T_c33ec_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_c33ec_row1_col3" class="data row1 col3" >0.4000</td>
#       <td id="T_c33ec_row1_col4" class="data row1 col4" >0.5714</td>
#     </tr>
#     <tr>
#       <th id="T_c33ec_level0_row2" class="row_heading level0 row2" >Xray</th>
#       <td id="T_c33ec_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_c33ec_row2_col1" class="data row2 col1" >0.9000</td>
#       <td id="T_c33ec_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_c33ec_row2_col3" class="data row2 col3" >0.8000</td>
#       <td id="T_c33ec_row2_col4" class="data row2 col4" >0.8889</td>
#     </tr>
#   </tbody>
# </table>
# 🤖 MEDGEMMA — Clean baseline
# <style type="text/css">
# #T_b41ce_row0_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b41ce_row1_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b41ce_row2_col4 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b41ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b41ce_level0_col0" class="col_heading level0 col0" >n_samples</th>
#       <th id="T_b41ce_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_b41ce_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_b41ce_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_b41ce_level0_col4" class="col_heading level0 col4" >f1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b41ce_level0_row0" class="row_heading level0 row0" >MRI</th>
#       <td id="T_b41ce_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_b41ce_row0_col1" class="data row0 col1" >0.8500</td>
#       <td id="T_b41ce_row0_col2" class="data row0 col2" >0.7692</td>
#       <td id="T_b41ce_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_b41ce_row0_col4" class="data row0 col4" >0.8696</td>
#     </tr>
#     <tr>
#       <th id="T_b41ce_level0_row1" class="row_heading level0 row1" >OCT</th>
#       <td id="T_b41ce_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_b41ce_row1_col1" class="data row1 col1" >0.5000</td>
#       <td id="T_b41ce_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_b41ce_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_b41ce_row1_col4" class="data row1 col4" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b41ce_level0_row2" class="row_heading level0 row2" >Xray</th>
#       <td id="T_b41ce_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_b41ce_row2_col1" class="data row2 col1" >0.8500</td>
#       <td id="T_b41ce_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_b41ce_row2_col3" class="data row2 col3" >0.7000</td>
#       <td id="T_b41ce_row2_col4" class="data row2 col4" >0.8235</td>
#     </tr>
#   </tbody>
# </table>
# 🤖 QWEN3 — Clean baseline
# <style type="text/css">
# #T_d873e_row0_col4 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_d873e_row1_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d873e_row2_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_d873e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d873e_level0_col0" class="col_heading level0 col0" >n_samples</th>
#       <th id="T_d873e_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_d873e_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_d873e_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_d873e_level0_col4" class="col_heading level0 col4" >f1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d873e_level0_row0" class="row_heading level0 row0" >MRI</th>
#       <td id="T_d873e_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_d873e_row0_col1" class="data row0 col1" >0.8000</td>
#       <td id="T_d873e_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_d873e_row0_col3" class="data row0 col3" >0.6000</td>
#       <td id="T_d873e_row0_col4" class="data row0 col4" >0.7500</td>
#     </tr>
#     <tr>
#       <th id="T_d873e_level0_row1" class="row_heading level0 row1" >OCT</th>
#       <td id="T_d873e_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_d873e_row1_col1" class="data row1 col1" >0.7500</td>
#       <td id="T_d873e_row1_col2" class="data row1 col2" >0.7273</td>
#       <td id="T_d873e_row1_col3" class="data row1 col3" >0.8000</td>
#       <td id="T_d873e_row1_col4" class="data row1 col4" >0.7619</td>
#     </tr>
#     <tr>
#       <th id="T_d873e_level0_row2" class="row_heading level0 row2" >Xray</th>
#       <td id="T_d873e_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_d873e_row2_col1" class="data row2 col1" >0.4000</td>
#       <td id="T_d873e_row2_col2" class="data row2 col2" >0.3333</td>
#       <td id="T_d873e_row2_col3" class="data row2 col3" >0.2000</td>
#       <td id="T_d873e_row2_col4" class="data row2 col4" >0.2500</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 1) Weak image performance

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from pathlib import Path

models = ["internvl", "lingshu", "medgemma", "qwen3"]

prompts = [
    "baseline-prompts",
    "disease-cue-reason-1-prompts",
    "disease_cue-1-prompts",
    "artefact-disease-cue-2-prompts",
    "artefact_disease_cue-1-prompts",
    "artefact-disease-cue-reason-1-prompts",
]

modalities = ["MRI", "OCT", "Xray"]

results = []

for model in models:
    for prompt in prompts:
        file = f"{model}_{prompt}.csv"
        if not Path(file).exists():
            continue

        df = pd.read_csv(file)

        # weak만
        df = df[df["severity"] == "weak"].copy()

        # 숫자 변환 (문자열/공백/이상값 방지)
        df["binarylabel"] = pd.to_numeric(df["binarylabel"], errors="coerce")
        df["pred_binary"] = pd.to_numeric(df["pred_binary"], errors="coerce")

        for mod in modalities:
            sub = df[df["dataset"] == mod].copy()
            if sub.empty:
                continue

            n_total = len(sub)
            n_gt_nan = int(sub["binarylabel"].isna().sum())
            n_pred_nan = int(sub["pred_binary"].isna().sum())

            # metric 계산 가능한 유효 row만 사용
            valid = sub.dropna(subset=["binarylabel", "pred_binary"]).copy()
            n_valid = len(valid)

            if n_valid == 0:
                results.append({
                    "model": model,
                    "prompt": prompt,
                    "dataset": mod,
                    "n_total": n_total,
                    "n_valid": 0,
                    "n_gt_nan": n_gt_nan,
                    "n_pred_nan": n_pred_nan,
                    "accuracy": None,
                    "precision": None,
                    "recall": None,
                    "f1": None,
                })
                continue

            y_true = valid["binarylabel"].astype(int)
            y_pred = valid["pred_binary"].astype(int)

            results.append({
                "model": model,
                "prompt": prompt,
                "dataset": mod,
                "n_total": n_total,
                "n_valid": n_valid,
                "n_gt_nan": n_gt_nan,
                "n_pred_nan": n_pred_nan,
                "accuracy": accuracy_score(y_true, y_pred),
                "precision": precision_score(y_true, y_pred, zero_division=0),
                "recall": recall_score(y_true, y_pred, zero_division=0),
                "f1": f1_score(y_true, y_pred, zero_division=0),
            })

results_df = pd.DataFrame(results)
pivot = results_df.pivot_table(
    index=["model", "prompt", "dataset"],
    values=["n_valid", "accuracy", "precision", "recall", "f1"],
    aggfunc="first",
).sort_index()

from IPython.display import display

model_order = ["internvl", "lingshu", "medgemma", "qwen3"]
dataset_order = ["MRI", "OCT", "Xray"]
metrics = ["n_valid", "accuracy", "precision", "recall", "f1"]

prompt_order = [
    "baseline-prompts",
    "disease_cue-1-prompts",
    "artefact_disease_cue-1-prompts",
    "artefact-disease-cue-2-prompts",
]


for prompt in prompt_order:
    df_p = results_df[results_df["prompt"] == prompt].copy()
    if df_p.empty:
        continue

    print(f"\n🧾 PROMPT: {prompt}\n" + "─" * 60)

    for model in model_order:
        df_pm = df_p[df_p["model"] == model].copy()
        if df_pm.empty:
            continue

        tbl = (
            df_pm
            .set_index("dataset")[metrics]
            .reindex(dataset_order)
        )

        print(f"\n🤖 Model: {model}")
        display(tbl.round(4))
# Out:
# 🧾 PROMPT: baseline-prompts
# ────────────────────────────────────────────────────────────
#
# 🤖 Model: internvl
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.77     1.0000    0.54  0.7013
# OCT          100      0.55     1.0000    0.10  0.1818
# Xray         100      0.63     0.9333    0.28  0.4308
# 🤖 Model: lingshu
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.89     0.9535    0.82  0.8817
# OCT          100      0.64     1.0000    0.28  0.4375
# Xray         100      0.69     0.6418    0.86  0.7350
# 🤖 Model: medgemma
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.85     0.8889    0.80  0.8421
# OCT          100      0.50     0.0000    0.00  0.0000
# Xray         100      0.56     1.0000    0.12  0.2143
# 🤖 Model: qwen3
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.66       1.00    0.32  0.4848
# OCT          100      0.54       0.75    0.12  0.2069
# Xray         100      0.56       1.00    0.12  0.2143
# 🧾 PROMPT: disease_cue-1-prompts
# ────────────────────────────────────────────────────────────
#
# 🤖 Model: internvl
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.72     1.0000    0.44  0.6111
# OCT          100      0.55     1.0000    0.10  0.1818
# Xray         100      0.67     0.9474    0.36  0.5217
# 🤖 Model: lingshu
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.88     0.9750    0.78  0.8667
# OCT          100      0.59     1.0000    0.18  0.3051
# Xray         100      0.71     0.7442    0.64  0.6882
# 🤖 Model: medgemma
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.86     0.8462    0.88  0.8627
# OCT          100      0.51     1.0000    0.02  0.0392
# Xray         100      0.62     1.0000    0.24  0.3871
# 🤖 Model: qwen3
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.68     1.0000    0.36  0.5294
# OCT          100      0.53     0.6667    0.12  0.2034
# Xray         100      0.57     1.0000    0.14  0.2456
# 🧾 PROMPT: artefact_disease_cue-1-prompts
# ────────────────────────────────────────────────────────────
#
# 🤖 Model: internvl
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.68        1.0    0.36  0.5294
# OCT          100      0.52        1.0    0.04  0.0769
# Xray         100      0.61        1.0    0.22  0.3607
# 🤖 Model: lingshu
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.84     0.9722    0.70  0.8140
# OCT          100      0.59     1.0000    0.18  0.3051
# Xray         100      0.71     0.7442    0.64  0.6882
# 🤖 Model: medgemma
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.86     0.8462    0.88  0.8627
# OCT          100      0.50     0.0000    0.00  0.0000
# Xray         100      0.62     1.0000    0.24  0.3871
# 🤖 Model: qwen3
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.62       1.00    0.24  0.3871
# OCT          100      0.52       0.75    0.06  0.1111
# Xray         100      0.52       1.00    0.04  0.0769
# 🧾 PROMPT: artefact-disease-cue-2-prompts
# ────────────────────────────────────────────────────────────
#
# 🤖 Model: internvl
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.69        1.0    0.38  0.5507
# OCT          100      0.52        1.0    0.04  0.0769
# Xray         100      0.61        1.0    0.22  0.3607
# 🤖 Model: lingshu
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.85     0.9730    0.72  0.8276
# OCT          100      0.59     1.0000    0.18  0.3051
# Xray         100      0.71     0.7442    0.64  0.6882
# 🤖 Model: medgemma
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.86     0.8462    0.88  0.8627
# OCT          100      0.50     0.0000    0.00  0.0000
# Xray         100      0.61     1.0000    0.22  0.3607
# 🤖 Model: qwen3
#          n_valid  accuracy  precision  recall      f1
# dataset
# MRI          100      0.62        1.0    0.24  0.3871
# OCT          100      0.50        0.0    0.00  0.0000
# Xray         100      0.52        1.0    0.04  0.0769

# %%
from IPython.display import display

model_order = ["internvl", "lingshu", "medgemma", "qwen3"]
dataset_order = ["MRI", "OCT", "Xray"]
metrics = ["accuracy", "precision", "recall", "f1"]

prompt_order = [
    "baseline-prompts",
    "disease-cue-reason-1-prompts",
    "disease_cue-1-prompts",
    "artefact-disease-cue-2-prompts",
    "artefact_disease_cue-1-prompts",
    "artefact-disease-cue-reason-1-prompts",
]
for prompt in prompt_order:
    df_p = results_df[results_df["prompt"] == prompt].copy()
    if df_p.empty:
        continue

    print(f"\n🧾 PROMPT: {prompt}")
    print("─" * 70)

    # (model, dataset)를 행으로
    tbl = (
        df_p
        .pivot_table(
            index=["model", "dataset"],
            values=["n_valid"] + metrics,
            aggfunc="first",
        )
        .reindex(
            pd.MultiIndex.from_product(
                [model_order, dataset_order],
                names=["model", "dataset"]
            )
        )
    )

    display(
        tbl.round(4)
        .style
        .background_gradient(subset=["f1"])
        .set_caption(f"Weak performance — Prompt: {prompt}")
    )
# Out:
# 🧾 PROMPT: baseline-prompts
# ──────────────────────────────────────────────────────────────────────
# <style type="text/css">
# #T_f89c2_row0_col1 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_f89c2_row1_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_f89c2_row2_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_f89c2_row3_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f89c2_row4_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_f89c2_row5_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_f89c2_row6_col1 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_f89c2_row7_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f89c2_row8_col1, #T_f89c2_row11_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_f89c2_row9_col1 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_f89c2_row10_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_f89c2">
#   <caption>Weak performance — Prompt: baseline-prompts</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f89c2_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_f89c2_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_f89c2_level0_col2" class="col_heading level0 col2" >n_valid</th>
#       <th id="T_f89c2_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_f89c2_level0_col4" class="col_heading level0 col4" >recall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f89c2_level0_row0" class="row_heading level0 row0" rowspan="3">internvl</th>
#       <th id="T_f89c2_level1_row0" class="row_heading level1 row0" >MRI</th>
#       <td id="T_f89c2_row0_col0" class="data row0 col0" >0.770000</td>
#       <td id="T_f89c2_row0_col1" class="data row0 col1" >0.701300</td>
#       <td id="T_f89c2_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_f89c2_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_f89c2_row0_col4" class="data row0 col4" >0.540000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level1_row1" class="row_heading level1 row1" >OCT</th>
#       <td id="T_f89c2_row1_col0" class="data row1 col0" >0.550000</td>
#       <td id="T_f89c2_row1_col1" class="data row1 col1" >0.181800</td>
#       <td id="T_f89c2_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_f89c2_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_f89c2_row1_col4" class="data row1 col4" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level1_row2" class="row_heading level1 row2" >Xray</th>
#       <td id="T_f89c2_row2_col0" class="data row2 col0" >0.630000</td>
#       <td id="T_f89c2_row2_col1" class="data row2 col1" >0.430800</td>
#       <td id="T_f89c2_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_f89c2_row2_col3" class="data row2 col3" >0.933300</td>
#       <td id="T_f89c2_row2_col4" class="data row2 col4" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level0_row3" class="row_heading level0 row3" rowspan="3">lingshu</th>
#       <th id="T_f89c2_level1_row3" class="row_heading level1 row3" >MRI</th>
#       <td id="T_f89c2_row3_col0" class="data row3 col0" >0.890000</td>
#       <td id="T_f89c2_row3_col1" class="data row3 col1" >0.881700</td>
#       <td id="T_f89c2_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_f89c2_row3_col3" class="data row3 col3" >0.953500</td>
#       <td id="T_f89c2_row3_col4" class="data row3 col4" >0.820000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level1_row4" class="row_heading level1 row4" >OCT</th>
#       <td id="T_f89c2_row4_col0" class="data row4 col0" >0.640000</td>
#       <td id="T_f89c2_row4_col1" class="data row4 col1" >0.437500</td>
#       <td id="T_f89c2_row4_col2" class="data row4 col2" >100</td>
#       <td id="T_f89c2_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_f89c2_row4_col4" class="data row4 col4" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level1_row5" class="row_heading level1 row5" >Xray</th>
#       <td id="T_f89c2_row5_col0" class="data row5 col0" >0.690000</td>
#       <td id="T_f89c2_row5_col1" class="data row5 col1" >0.735000</td>
#       <td id="T_f89c2_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_f89c2_row5_col3" class="data row5 col3" >0.641800</td>
#       <td id="T_f89c2_row5_col4" class="data row5 col4" >0.860000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level0_row6" class="row_heading level0 row6" rowspan="3">medgemma</th>
#       <th id="T_f89c2_level1_row6" class="row_heading level1 row6" >MRI</th>
#       <td id="T_f89c2_row6_col0" class="data row6 col0" >0.850000</td>
#       <td id="T_f89c2_row6_col1" class="data row6 col1" >0.842100</td>
#       <td id="T_f89c2_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_f89c2_row6_col3" class="data row6 col3" >0.888900</td>
#       <td id="T_f89c2_row6_col4" class="data row6 col4" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level1_row7" class="row_heading level1 row7" >OCT</th>
#       <td id="T_f89c2_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_f89c2_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_f89c2_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_f89c2_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_f89c2_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level1_row8" class="row_heading level1 row8" >Xray</th>
#       <td id="T_f89c2_row8_col0" class="data row8 col0" >0.560000</td>
#       <td id="T_f89c2_row8_col1" class="data row8 col1" >0.214300</td>
#       <td id="T_f89c2_row8_col2" class="data row8 col2" >100</td>
#       <td id="T_f89c2_row8_col3" class="data row8 col3" >1.000000</td>
#       <td id="T_f89c2_row8_col4" class="data row8 col4" >0.120000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level0_row9" class="row_heading level0 row9" rowspan="3">qwen3</th>
#       <th id="T_f89c2_level1_row9" class="row_heading level1 row9" >MRI</th>
#       <td id="T_f89c2_row9_col0" class="data row9 col0" >0.660000</td>
#       <td id="T_f89c2_row9_col1" class="data row9 col1" >0.484800</td>
#       <td id="T_f89c2_row9_col2" class="data row9 col2" >100</td>
#       <td id="T_f89c2_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_f89c2_row9_col4" class="data row9 col4" >0.320000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level1_row10" class="row_heading level1 row10" >OCT</th>
#       <td id="T_f89c2_row10_col0" class="data row10 col0" >0.540000</td>
#       <td id="T_f89c2_row10_col1" class="data row10 col1" >0.206900</td>
#       <td id="T_f89c2_row10_col2" class="data row10 col2" >100</td>
#       <td id="T_f89c2_row10_col3" class="data row10 col3" >0.750000</td>
#       <td id="T_f89c2_row10_col4" class="data row10 col4" >0.120000</td>
#     </tr>
#     <tr>
#       <th id="T_f89c2_level1_row11" class="row_heading level1 row11" >Xray</th>
#       <td id="T_f89c2_row11_col0" class="data row11 col0" >0.560000</td>
#       <td id="T_f89c2_row11_col1" class="data row11 col1" >0.214300</td>
#       <td id="T_f89c2_row11_col2" class="data row11 col2" >100</td>
#       <td id="T_f89c2_row11_col3" class="data row11 col3" >1.000000</td>
#       <td id="T_f89c2_row11_col4" class="data row11 col4" >0.120000</td>
#     </tr>
#   </tbody>
# </table>
# 🧾 PROMPT: disease-cue-reason-1-prompts
# ──────────────────────────────────────────────────────────────────────
# <style type="text/css">
# #T_32623_row0_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_32623_row1_col1, #T_32623_row7_col1, #T_32623_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_32623_row2_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_32623_row3_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_32623_row4_col1, #T_32623_row9_col1 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_32623_row5_col1 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_32623_row6_col1 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_32623_row8_col1, #T_32623_row11_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# </style>
# <table id="T_32623">
#   <caption>Weak performance — Prompt: disease-cue-reason-1-prompts</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32623_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_32623_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_32623_level0_col2" class="col_heading level0 col2" >n_valid</th>
#       <th id="T_32623_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_32623_level0_col4" class="col_heading level0 col4" >recall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32623_level0_row0" class="row_heading level0 row0" rowspan="3">internvl</th>
#       <th id="T_32623_level1_row0" class="row_heading level1 row0" >MRI</th>
#       <td id="T_32623_row0_col0" class="data row0 col0" >0.560000</td>
#       <td id="T_32623_row0_col1" class="data row0 col1" >0.214300</td>
#       <td id="T_32623_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_32623_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_32623_row0_col4" class="data row0 col4" >0.120000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level1_row1" class="row_heading level1 row1" >OCT</th>
#       <td id="T_32623_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_32623_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_32623_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_32623_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_32623_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level1_row2" class="row_heading level1 row2" >Xray</th>
#       <td id="T_32623_row2_col0" class="data row2 col0" >0.520000</td>
#       <td id="T_32623_row2_col1" class="data row2 col1" >0.076900</td>
#       <td id="T_32623_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_32623_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_32623_row2_col4" class="data row2 col4" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level0_row3" class="row_heading level0 row3" rowspan="3">lingshu</th>
#       <th id="T_32623_level1_row3" class="row_heading level1 row3" >MRI</th>
#       <td id="T_32623_row3_col0" class="data row3 col0" >0.830000</td>
#       <td id="T_32623_row3_col1" class="data row3 col1" >0.800000</td>
#       <td id="T_32623_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_32623_row3_col3" class="data row3 col3" >0.971400</td>
#       <td id="T_32623_row3_col4" class="data row3 col4" >0.680000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level1_row4" class="row_heading level1 row4" >OCT</th>
#       <td id="T_32623_row4_col0" class="data row4 col0" >0.590000</td>
#       <td id="T_32623_row4_col1" class="data row4 col1" >0.305100</td>
#       <td id="T_32623_row4_col2" class="data row4 col2" >100</td>
#       <td id="T_32623_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_32623_row4_col4" class="data row4 col4" >0.180000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level1_row5" class="row_heading level1 row5" >Xray</th>
#       <td id="T_32623_row5_col0" class="data row5 col0" >0.700000</td>
#       <td id="T_32623_row5_col1" class="data row5 col1" >0.680900</td>
#       <td id="T_32623_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_32623_row5_col3" class="data row5 col3" >0.727300</td>
#       <td id="T_32623_row5_col4" class="data row5 col4" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level0_row6" class="row_heading level0 row6" rowspan="3">medgemma</th>
#       <th id="T_32623_level1_row6" class="row_heading level1 row6" >MRI</th>
#       <td id="T_32623_row6_col0" class="data row6 col0" >0.810000</td>
#       <td id="T_32623_row6_col1" class="data row6 col1" >0.771100</td>
#       <td id="T_32623_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_32623_row6_col3" class="data row6 col3" >0.969700</td>
#       <td id="T_32623_row6_col4" class="data row6 col4" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level1_row7" class="row_heading level1 row7" >OCT</th>
#       <td id="T_32623_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_32623_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_32623_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_32623_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_32623_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level1_row8" class="row_heading level1 row8" >Xray</th>
#       <td id="T_32623_row8_col0" class="data row8 col0" >0.530000</td>
#       <td id="T_32623_row8_col1" class="data row8 col1" >0.113200</td>
#       <td id="T_32623_row8_col2" class="data row8 col2" >100</td>
#       <td id="T_32623_row8_col3" class="data row8 col3" >1.000000</td>
#       <td id="T_32623_row8_col4" class="data row8 col4" >0.060000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level0_row9" class="row_heading level0 row9" rowspan="3">qwen3</th>
#       <th id="T_32623_level1_row9" class="row_heading level1 row9" >MRI</th>
#       <td id="T_32623_row9_col0" class="data row9 col0" >0.590000</td>
#       <td id="T_32623_row9_col1" class="data row9 col1" >0.305100</td>
#       <td id="T_32623_row9_col2" class="data row9 col2" >100</td>
#       <td id="T_32623_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_32623_row9_col4" class="data row9 col4" >0.180000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level1_row10" class="row_heading level1 row10" >OCT</th>
#       <td id="T_32623_row10_col0" class="data row10 col0" >0.500000</td>
#       <td id="T_32623_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_32623_row10_col2" class="data row10 col2" >100</td>
#       <td id="T_32623_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_32623_row10_col4" class="data row10 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_32623_level1_row11" class="row_heading level1 row11" >Xray</th>
#       <td id="T_32623_row11_col0" class="data row11 col0" >0.530000</td>
#       <td id="T_32623_row11_col1" class="data row11 col1" >0.113200</td>
#       <td id="T_32623_row11_col2" class="data row11 col2" >100</td>
#       <td id="T_32623_row11_col3" class="data row11 col3" >1.000000</td>
#       <td id="T_32623_row11_col4" class="data row11 col4" >0.060000</td>
#     </tr>
#   </tbody>
# </table>
# 🧾 PROMPT: disease_cue-1-prompts
# ──────────────────────────────────────────────────────────────────────
# <style type="text/css">
# #T_66e0f_row0_col1 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_66e0f_row1_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_66e0f_row2_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_66e0f_row3_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_66e0f_row4_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_66e0f_row5_col1 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_66e0f_row6_col1 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_66e0f_row7_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_66e0f_row8_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_66e0f_row9_col1 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_66e0f_row10_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_66e0f_row11_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# </style>
# <table id="T_66e0f">
#   <caption>Weak performance — Prompt: disease_cue-1-prompts</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66e0f_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_66e0f_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_66e0f_level0_col2" class="col_heading level0 col2" >n_valid</th>
#       <th id="T_66e0f_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_66e0f_level0_col4" class="col_heading level0 col4" >recall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66e0f_level0_row0" class="row_heading level0 row0" rowspan="3">internvl</th>
#       <th id="T_66e0f_level1_row0" class="row_heading level1 row0" >MRI</th>
#       <td id="T_66e0f_row0_col0" class="data row0 col0" >0.720000</td>
#       <td id="T_66e0f_row0_col1" class="data row0 col1" >0.611100</td>
#       <td id="T_66e0f_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_66e0f_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_66e0f_row0_col4" class="data row0 col4" >0.440000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level1_row1" class="row_heading level1 row1" >OCT</th>
#       <td id="T_66e0f_row1_col0" class="data row1 col0" >0.550000</td>
#       <td id="T_66e0f_row1_col1" class="data row1 col1" >0.181800</td>
#       <td id="T_66e0f_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_66e0f_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_66e0f_row1_col4" class="data row1 col4" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level1_row2" class="row_heading level1 row2" >Xray</th>
#       <td id="T_66e0f_row2_col0" class="data row2 col0" >0.670000</td>
#       <td id="T_66e0f_row2_col1" class="data row2 col1" >0.521700</td>
#       <td id="T_66e0f_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_66e0f_row2_col3" class="data row2 col3" >0.947400</td>
#       <td id="T_66e0f_row2_col4" class="data row2 col4" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level0_row3" class="row_heading level0 row3" rowspan="3">lingshu</th>
#       <th id="T_66e0f_level1_row3" class="row_heading level1 row3" >MRI</th>
#       <td id="T_66e0f_row3_col0" class="data row3 col0" >0.880000</td>
#       <td id="T_66e0f_row3_col1" class="data row3 col1" >0.866700</td>
#       <td id="T_66e0f_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_66e0f_row3_col3" class="data row3 col3" >0.975000</td>
#       <td id="T_66e0f_row3_col4" class="data row3 col4" >0.780000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level1_row4" class="row_heading level1 row4" >OCT</th>
#       <td id="T_66e0f_row4_col0" class="data row4 col0" >0.590000</td>
#       <td id="T_66e0f_row4_col1" class="data row4 col1" >0.305100</td>
#       <td id="T_66e0f_row4_col2" class="data row4 col2" >100</td>
#       <td id="T_66e0f_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_66e0f_row4_col4" class="data row4 col4" >0.180000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level1_row5" class="row_heading level1 row5" >Xray</th>
#       <td id="T_66e0f_row5_col0" class="data row5 col0" >0.710000</td>
#       <td id="T_66e0f_row5_col1" class="data row5 col1" >0.688200</td>
#       <td id="T_66e0f_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_66e0f_row5_col3" class="data row5 col3" >0.744200</td>
#       <td id="T_66e0f_row5_col4" class="data row5 col4" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level0_row6" class="row_heading level0 row6" rowspan="3">medgemma</th>
#       <th id="T_66e0f_level1_row6" class="row_heading level1 row6" >MRI</th>
#       <td id="T_66e0f_row6_col0" class="data row6 col0" >0.860000</td>
#       <td id="T_66e0f_row6_col1" class="data row6 col1" >0.862700</td>
#       <td id="T_66e0f_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_66e0f_row6_col3" class="data row6 col3" >0.846200</td>
#       <td id="T_66e0f_row6_col4" class="data row6 col4" >0.880000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level1_row7" class="row_heading level1 row7" >OCT</th>
#       <td id="T_66e0f_row7_col0" class="data row7 col0" >0.510000</td>
#       <td id="T_66e0f_row7_col1" class="data row7 col1" >0.039200</td>
#       <td id="T_66e0f_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_66e0f_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_66e0f_row7_col4" class="data row7 col4" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level1_row8" class="row_heading level1 row8" >Xray</th>
#       <td id="T_66e0f_row8_col0" class="data row8 col0" >0.620000</td>
#       <td id="T_66e0f_row8_col1" class="data row8 col1" >0.387100</td>
#       <td id="T_66e0f_row8_col2" class="data row8 col2" >100</td>
#       <td id="T_66e0f_row8_col3" class="data row8 col3" >1.000000</td>
#       <td id="T_66e0f_row8_col4" class="data row8 col4" >0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level0_row9" class="row_heading level0 row9" rowspan="3">qwen3</th>
#       <th id="T_66e0f_level1_row9" class="row_heading level1 row9" >MRI</th>
#       <td id="T_66e0f_row9_col0" class="data row9 col0" >0.680000</td>
#       <td id="T_66e0f_row9_col1" class="data row9 col1" >0.529400</td>
#       <td id="T_66e0f_row9_col2" class="data row9 col2" >100</td>
#       <td id="T_66e0f_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_66e0f_row9_col4" class="data row9 col4" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level1_row10" class="row_heading level1 row10" >OCT</th>
#       <td id="T_66e0f_row10_col0" class="data row10 col0" >0.530000</td>
#       <td id="T_66e0f_row10_col1" class="data row10 col1" >0.203400</td>
#       <td id="T_66e0f_row10_col2" class="data row10 col2" >100</td>
#       <td id="T_66e0f_row10_col3" class="data row10 col3" >0.666700</td>
#       <td id="T_66e0f_row10_col4" class="data row10 col4" >0.120000</td>
#     </tr>
#     <tr>
#       <th id="T_66e0f_level1_row11" class="row_heading level1 row11" >Xray</th>
#       <td id="T_66e0f_row11_col0" class="data row11 col0" >0.570000</td>
#       <td id="T_66e0f_row11_col1" class="data row11 col1" >0.245600</td>
#       <td id="T_66e0f_row11_col2" class="data row11 col2" >100</td>
#       <td id="T_66e0f_row11_col3" class="data row11 col3" >1.000000</td>
#       <td id="T_66e0f_row11_col4" class="data row11 col4" >0.140000</td>
#     </tr>
#   </tbody>
# </table>
# 🧾 PROMPT: artefact-disease-cue-2-prompts
# ──────────────────────────────────────────────────────────────────────
# <style type="text/css">
# #T_a1c46_row0_col1 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_a1c46_row1_col1, #T_a1c46_row11_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a1c46_row2_col1, #T_a1c46_row8_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_a1c46_row3_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_a1c46_row4_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_a1c46_row5_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_a1c46_row6_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a1c46_row7_col1, #T_a1c46_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a1c46_row9_col1 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# </style>
# <table id="T_a1c46">
#   <caption>Weak performance — Prompt: artefact-disease-cue-2-prompts</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1c46_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_a1c46_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_a1c46_level0_col2" class="col_heading level0 col2" >n_valid</th>
#       <th id="T_a1c46_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_a1c46_level0_col4" class="col_heading level0 col4" >recall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1c46_level0_row0" class="row_heading level0 row0" rowspan="3">internvl</th>
#       <th id="T_a1c46_level1_row0" class="row_heading level1 row0" >MRI</th>
#       <td id="T_a1c46_row0_col0" class="data row0 col0" >0.690000</td>
#       <td id="T_a1c46_row0_col1" class="data row0 col1" >0.550700</td>
#       <td id="T_a1c46_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_a1c46_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_a1c46_row0_col4" class="data row0 col4" >0.380000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level1_row1" class="row_heading level1 row1" >OCT</th>
#       <td id="T_a1c46_row1_col0" class="data row1 col0" >0.520000</td>
#       <td id="T_a1c46_row1_col1" class="data row1 col1" >0.076900</td>
#       <td id="T_a1c46_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_a1c46_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_a1c46_row1_col4" class="data row1 col4" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level1_row2" class="row_heading level1 row2" >Xray</th>
#       <td id="T_a1c46_row2_col0" class="data row2 col0" >0.610000</td>
#       <td id="T_a1c46_row2_col1" class="data row2 col1" >0.360700</td>
#       <td id="T_a1c46_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_a1c46_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_a1c46_row2_col4" class="data row2 col4" >0.220000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level0_row3" class="row_heading level0 row3" rowspan="3">lingshu</th>
#       <th id="T_a1c46_level1_row3" class="row_heading level1 row3" >MRI</th>
#       <td id="T_a1c46_row3_col0" class="data row3 col0" >0.850000</td>
#       <td id="T_a1c46_row3_col1" class="data row3 col1" >0.827600</td>
#       <td id="T_a1c46_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_a1c46_row3_col3" class="data row3 col3" >0.973000</td>
#       <td id="T_a1c46_row3_col4" class="data row3 col4" >0.720000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level1_row4" class="row_heading level1 row4" >OCT</th>
#       <td id="T_a1c46_row4_col0" class="data row4 col0" >0.590000</td>
#       <td id="T_a1c46_row4_col1" class="data row4 col1" >0.305100</td>
#       <td id="T_a1c46_row4_col2" class="data row4 col2" >100</td>
#       <td id="T_a1c46_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_a1c46_row4_col4" class="data row4 col4" >0.180000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level1_row5" class="row_heading level1 row5" >Xray</th>
#       <td id="T_a1c46_row5_col0" class="data row5 col0" >0.710000</td>
#       <td id="T_a1c46_row5_col1" class="data row5 col1" >0.688200</td>
#       <td id="T_a1c46_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_a1c46_row5_col3" class="data row5 col3" >0.744200</td>
#       <td id="T_a1c46_row5_col4" class="data row5 col4" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level0_row6" class="row_heading level0 row6" rowspan="3">medgemma</th>
#       <th id="T_a1c46_level1_row6" class="row_heading level1 row6" >MRI</th>
#       <td id="T_a1c46_row6_col0" class="data row6 col0" >0.860000</td>
#       <td id="T_a1c46_row6_col1" class="data row6 col1" >0.862700</td>
#       <td id="T_a1c46_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_a1c46_row6_col3" class="data row6 col3" >0.846200</td>
#       <td id="T_a1c46_row6_col4" class="data row6 col4" >0.880000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level1_row7" class="row_heading level1 row7" >OCT</th>
#       <td id="T_a1c46_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_a1c46_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_a1c46_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_a1c46_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_a1c46_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level1_row8" class="row_heading level1 row8" >Xray</th>
#       <td id="T_a1c46_row8_col0" class="data row8 col0" >0.610000</td>
#       <td id="T_a1c46_row8_col1" class="data row8 col1" >0.360700</td>
#       <td id="T_a1c46_row8_col2" class="data row8 col2" >100</td>
#       <td id="T_a1c46_row8_col3" class="data row8 col3" >1.000000</td>
#       <td id="T_a1c46_row8_col4" class="data row8 col4" >0.220000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level0_row9" class="row_heading level0 row9" rowspan="3">qwen3</th>
#       <th id="T_a1c46_level1_row9" class="row_heading level1 row9" >MRI</th>
#       <td id="T_a1c46_row9_col0" class="data row9 col0" >0.620000</td>
#       <td id="T_a1c46_row9_col1" class="data row9 col1" >0.387100</td>
#       <td id="T_a1c46_row9_col2" class="data row9 col2" >100</td>
#       <td id="T_a1c46_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_a1c46_row9_col4" class="data row9 col4" >0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level1_row10" class="row_heading level1 row10" >OCT</th>
#       <td id="T_a1c46_row10_col0" class="data row10 col0" >0.500000</td>
#       <td id="T_a1c46_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_a1c46_row10_col2" class="data row10 col2" >100</td>
#       <td id="T_a1c46_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_a1c46_row10_col4" class="data row10 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1c46_level1_row11" class="row_heading level1 row11" >Xray</th>
#       <td id="T_a1c46_row11_col0" class="data row11 col0" >0.520000</td>
#       <td id="T_a1c46_row11_col1" class="data row11 col1" >0.076900</td>
#       <td id="T_a1c46_row11_col2" class="data row11 col2" >100</td>
#       <td id="T_a1c46_row11_col3" class="data row11 col3" >1.000000</td>
#       <td id="T_a1c46_row11_col4" class="data row11 col4" >0.040000</td>
#     </tr>
#   </tbody>
# </table>
# 🧾 PROMPT: artefact_disease_cue-1-prompts
# ──────────────────────────────────────────────────────────────────────
# <style type="text/css">
# #T_e3956_row0_col1 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_e3956_row1_col1, #T_e3956_row11_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_e3956_row2_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_e3956_row3_col1 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_e3956_row4_col1 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_e3956_row5_col1 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_e3956_row6_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e3956_row7_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e3956_row8_col1, #T_e3956_row9_col1 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_e3956_row10_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# </style>
# <table id="T_e3956">
#   <caption>Weak performance — Prompt: artefact_disease_cue-1-prompts</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3956_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_e3956_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_e3956_level0_col2" class="col_heading level0 col2" >n_valid</th>
#       <th id="T_e3956_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_e3956_level0_col4" class="col_heading level0 col4" >recall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3956_level0_row0" class="row_heading level0 row0" rowspan="3">internvl</th>
#       <th id="T_e3956_level1_row0" class="row_heading level1 row0" >MRI</th>
#       <td id="T_e3956_row0_col0" class="data row0 col0" >0.680000</td>
#       <td id="T_e3956_row0_col1" class="data row0 col1" >0.529400</td>
#       <td id="T_e3956_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_e3956_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_e3956_row0_col4" class="data row0 col4" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level1_row1" class="row_heading level1 row1" >OCT</th>
#       <td id="T_e3956_row1_col0" class="data row1 col0" >0.520000</td>
#       <td id="T_e3956_row1_col1" class="data row1 col1" >0.076900</td>
#       <td id="T_e3956_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_e3956_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_e3956_row1_col4" class="data row1 col4" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level1_row2" class="row_heading level1 row2" >Xray</th>
#       <td id="T_e3956_row2_col0" class="data row2 col0" >0.610000</td>
#       <td id="T_e3956_row2_col1" class="data row2 col1" >0.360700</td>
#       <td id="T_e3956_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_e3956_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_e3956_row2_col4" class="data row2 col4" >0.220000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level0_row3" class="row_heading level0 row3" rowspan="3">lingshu</th>
#       <th id="T_e3956_level1_row3" class="row_heading level1 row3" >MRI</th>
#       <td id="T_e3956_row3_col0" class="data row3 col0" >0.840000</td>
#       <td id="T_e3956_row3_col1" class="data row3 col1" >0.814000</td>
#       <td id="T_e3956_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_e3956_row3_col3" class="data row3 col3" >0.972200</td>
#       <td id="T_e3956_row3_col4" class="data row3 col4" >0.700000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level1_row4" class="row_heading level1 row4" >OCT</th>
#       <td id="T_e3956_row4_col0" class="data row4 col0" >0.590000</td>
#       <td id="T_e3956_row4_col1" class="data row4 col1" >0.305100</td>
#       <td id="T_e3956_row4_col2" class="data row4 col2" >100</td>
#       <td id="T_e3956_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_e3956_row4_col4" class="data row4 col4" >0.180000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level1_row5" class="row_heading level1 row5" >Xray</th>
#       <td id="T_e3956_row5_col0" class="data row5 col0" >0.710000</td>
#       <td id="T_e3956_row5_col1" class="data row5 col1" >0.688200</td>
#       <td id="T_e3956_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_e3956_row5_col3" class="data row5 col3" >0.744200</td>
#       <td id="T_e3956_row5_col4" class="data row5 col4" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level0_row6" class="row_heading level0 row6" rowspan="3">medgemma</th>
#       <th id="T_e3956_level1_row6" class="row_heading level1 row6" >MRI</th>
#       <td id="T_e3956_row6_col0" class="data row6 col0" >0.860000</td>
#       <td id="T_e3956_row6_col1" class="data row6 col1" >0.862700</td>
#       <td id="T_e3956_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_e3956_row6_col3" class="data row6 col3" >0.846200</td>
#       <td id="T_e3956_row6_col4" class="data row6 col4" >0.880000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level1_row7" class="row_heading level1 row7" >OCT</th>
#       <td id="T_e3956_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_e3956_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_e3956_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_e3956_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_e3956_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level1_row8" class="row_heading level1 row8" >Xray</th>
#       <td id="T_e3956_row8_col0" class="data row8 col0" >0.620000</td>
#       <td id="T_e3956_row8_col1" class="data row8 col1" >0.387100</td>
#       <td id="T_e3956_row8_col2" class="data row8 col2" >100</td>
#       <td id="T_e3956_row8_col3" class="data row8 col3" >1.000000</td>
#       <td id="T_e3956_row8_col4" class="data row8 col4" >0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level0_row9" class="row_heading level0 row9" rowspan="3">qwen3</th>
#       <th id="T_e3956_level1_row9" class="row_heading level1 row9" >MRI</th>
#       <td id="T_e3956_row9_col0" class="data row9 col0" >0.620000</td>
#       <td id="T_e3956_row9_col1" class="data row9 col1" >0.387100</td>
#       <td id="T_e3956_row9_col2" class="data row9 col2" >100</td>
#       <td id="T_e3956_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_e3956_row9_col4" class="data row9 col4" >0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level1_row10" class="row_heading level1 row10" >OCT</th>
#       <td id="T_e3956_row10_col0" class="data row10 col0" >0.520000</td>
#       <td id="T_e3956_row10_col1" class="data row10 col1" >0.111100</td>
#       <td id="T_e3956_row10_col2" class="data row10 col2" >100</td>
#       <td id="T_e3956_row10_col3" class="data row10 col3" >0.750000</td>
#       <td id="T_e3956_row10_col4" class="data row10 col4" >0.060000</td>
#     </tr>
#     <tr>
#       <th id="T_e3956_level1_row11" class="row_heading level1 row11" >Xray</th>
#       <td id="T_e3956_row11_col0" class="data row11 col0" >0.520000</td>
#       <td id="T_e3956_row11_col1" class="data row11 col1" >0.076900</td>
#       <td id="T_e3956_row11_col2" class="data row11 col2" >100</td>
#       <td id="T_e3956_row11_col3" class="data row11 col3" >1.000000</td>
#       <td id="T_e3956_row11_col4" class="data row11 col4" >0.040000</td>
#     </tr>
#   </tbody>
# </table>
# 🧾 PROMPT: artefact-disease-cue-reason-1-prompts
# ──────────────────────────────────────────────────────────────────────
# <style type="text/css">
# #T_d7b5d_row0_col1 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_d7b5d_row1_col1, #T_d7b5d_row7_col1, #T_d7b5d_row10_col1, #T_d7b5d_row11_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d7b5d_row2_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d7b5d_row3_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d7b5d_row4_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_d7b5d_row5_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_d7b5d_row6_col1 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_d7b5d_row8_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_d7b5d_row9_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# </style>
# <table id="T_d7b5d">
#   <caption>Weak performance — Prompt: artefact-disease-cue-reason-1-prompts</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7b5d_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_d7b5d_level0_col1" class="col_heading level0 col1" >f1</th>
#       <th id="T_d7b5d_level0_col2" class="col_heading level0 col2" >n_valid</th>
#       <th id="T_d7b5d_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_d7b5d_level0_col4" class="col_heading level0 col4" >recall</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7b5d_level0_row0" class="row_heading level0 row0" rowspan="3">internvl</th>
#       <th id="T_d7b5d_level1_row0" class="row_heading level1 row0" >MRI</th>
#       <td id="T_d7b5d_row0_col0" class="data row0 col0" >0.560000</td>
#       <td id="T_d7b5d_row0_col1" class="data row0 col1" >0.214300</td>
#       <td id="T_d7b5d_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_d7b5d_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_d7b5d_row0_col4" class="data row0 col4" >0.120000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level1_row1" class="row_heading level1 row1" >OCT</th>
#       <td id="T_d7b5d_row1_col0" class="data row1 col0" >0.500000</td>
#       <td id="T_d7b5d_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_d7b5d_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_d7b5d_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_d7b5d_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level1_row2" class="row_heading level1 row2" >Xray</th>
#       <td id="T_d7b5d_row2_col0" class="data row2 col0" >0.510000</td>
#       <td id="T_d7b5d_row2_col1" class="data row2 col1" >0.039200</td>
#       <td id="T_d7b5d_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_d7b5d_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_d7b5d_row2_col4" class="data row2 col4" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level0_row3" class="row_heading level0 row3" rowspan="3">lingshu</th>
#       <th id="T_d7b5d_level1_row3" class="row_heading level1 row3" >MRI</th>
#       <td id="T_d7b5d_row3_col0" class="data row3 col0" >0.820000</td>
#       <td id="T_d7b5d_row3_col1" class="data row3 col1" >0.785700</td>
#       <td id="T_d7b5d_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_d7b5d_row3_col3" class="data row3 col3" >0.970600</td>
#       <td id="T_d7b5d_row3_col4" class="data row3 col4" >0.660000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level1_row4" class="row_heading level1 row4" >OCT</th>
#       <td id="T_d7b5d_row4_col0" class="data row4 col0" >0.580000</td>
#       <td id="T_d7b5d_row4_col1" class="data row4 col1" >0.275900</td>
#       <td id="T_d7b5d_row4_col2" class="data row4 col2" >100</td>
#       <td id="T_d7b5d_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_d7b5d_row4_col4" class="data row4 col4" >0.160000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level1_row5" class="row_heading level1 row5" >Xray</th>
#       <td id="T_d7b5d_row5_col0" class="data row5 col0" >0.700000</td>
#       <td id="T_d7b5d_row5_col1" class="data row5 col1" >0.673900</td>
#       <td id="T_d7b5d_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_d7b5d_row5_col3" class="data row5 col3" >0.738100</td>
#       <td id="T_d7b5d_row5_col4" class="data row5 col4" >0.620000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level0_row6" class="row_heading level0 row6" rowspan="3">medgemma</th>
#       <th id="T_d7b5d_level1_row6" class="row_heading level1 row6" >MRI</th>
#       <td id="T_d7b5d_row6_col0" class="data row6 col0" >0.810000</td>
#       <td id="T_d7b5d_row6_col1" class="data row6 col1" >0.771100</td>
#       <td id="T_d7b5d_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_d7b5d_row6_col3" class="data row6 col3" >0.969700</td>
#       <td id="T_d7b5d_row6_col4" class="data row6 col4" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level1_row7" class="row_heading level1 row7" >OCT</th>
#       <td id="T_d7b5d_row7_col0" class="data row7 col0" >0.500000</td>
#       <td id="T_d7b5d_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_d7b5d_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_d7b5d_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_d7b5d_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level1_row8" class="row_heading level1 row8" >Xray</th>
#       <td id="T_d7b5d_row8_col0" class="data row8 col0" >0.520000</td>
#       <td id="T_d7b5d_row8_col1" class="data row8 col1" >0.076900</td>
#       <td id="T_d7b5d_row8_col2" class="data row8 col2" >100</td>
#       <td id="T_d7b5d_row8_col3" class="data row8 col3" >1.000000</td>
#       <td id="T_d7b5d_row8_col4" class="data row8 col4" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level0_row9" class="row_heading level0 row9" rowspan="3">qwen3</th>
#       <th id="T_d7b5d_level1_row9" class="row_heading level1 row9" >MRI</th>
#       <td id="T_d7b5d_row9_col0" class="data row9 col0" >0.530000</td>
#       <td id="T_d7b5d_row9_col1" class="data row9 col1" >0.113200</td>
#       <td id="T_d7b5d_row9_col2" class="data row9 col2" >100</td>
#       <td id="T_d7b5d_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_d7b5d_row9_col4" class="data row9 col4" >0.060000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level1_row10" class="row_heading level1 row10" >OCT</th>
#       <td id="T_d7b5d_row10_col0" class="data row10 col0" >0.500000</td>
#       <td id="T_d7b5d_row10_col1" class="data row10 col1" >0.000000</td>
#       <td id="T_d7b5d_row10_col2" class="data row10 col2" >100</td>
#       <td id="T_d7b5d_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_d7b5d_row10_col4" class="data row10 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d7b5d_level1_row11" class="row_heading level1 row11" >Xray</th>
#       <td id="T_d7b5d_row11_col0" class="data row11 col0" >0.500000</td>
#       <td id="T_d7b5d_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_d7b5d_row11_col2" class="data row11 col2" >100</td>
#       <td id="T_d7b5d_row11_col3" class="data row11 col3" >0.000000</td>
#       <td id="T_d7b5d_row11_col4" class="data row11 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
from pathlib import Path
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from IPython.display import display

# =========================
# 0) 설정
# =========================
models = ["internvl", "lingshu", "medgemma", "qwen3"]

prompts = [
    "baseline-prompts",
    "disease-cue-reason-1-prompts",
    "disease_cue-1-prompts",
    "artefact-disease-cue-2-prompts",
    "artefact_disease_cue-1-prompts",
    "artefact-disease-cue-reason-1-prompts",
]

datasets = ["MRI", "OCT", "Xray"]  # ✅ Xray로 고정
BEST_METRIC = "f1"                # best 기준 (추천: f1)

clean_files = {
    "internvl": "internvl_clean_baseline.csv",
    "lingshu": "lingshu_clean_baseline.csv",
    "medgemma": "medgemma_clean_baseline.csv",
    "qwen3": "qwen3_clean_baseline.csv",
}

def norm_dataset(s: pd.Series) -> pd.Series:
    return s.replace({"XRAY": "Xray", "XRay": "Xray", "xray": "Xray"})

# =========================
# 1) Clean metrics
# =========================
clean_rows = []
for model, path in clean_files.items():
    if not Path(path).exists():
        print(f"⚠️ missing clean file: {path}")
        continue

    df = pd.read_csv(path)
    df["dataset"] = norm_dataset(df["dataset"])
    df["gt_binary"] = pd.to_numeric(df["gt_binary"], errors="coerce")
    df["pred_binary"] = pd.to_numeric(df["pred_binary"], errors="coerce")

    for ds in datasets:
        sub = df[df["dataset"] == ds].copy()
        if sub.empty:
            continue
        valid = sub.dropna(subset=["gt_binary", "pred_binary"]).copy()
        if valid.empty:
            continue

        y_true = valid["gt_binary"].astype(int)
        y_pred = valid["pred_binary"].astype(int)

        clean_rows.append({
            "model": model,
            "dataset": ds,
            "clean_n": len(valid),
            "clean_accuracy": accuracy_score(y_true, y_pred),
            "clean_precision": precision_score(y_true, y_pred, zero_division=0),
            "clean_recall": recall_score(y_true, y_pred, zero_division=0),
            "clean_f1": f1_score(y_true, y_pred, zero_division=0),
        })

clean_df = pd.DataFrame(clean_rows)

# =========================
# 2) Weak metrics (severity=weak)
# =========================
weak_rows = []
for model in models:
    for prompt in prompts:
        file = f"{model}_{prompt}.csv"
        if not Path(file).exists():
            continue

        df = pd.read_csv(file)
        df = df[df["severity"] == "weak"].copy()

        df["dataset"] = norm_dataset(df["dataset"])
        df["binarylabel"] = pd.to_numeric(df["binarylabel"], errors="coerce")
        df["pred_binary"] = pd.to_numeric(df["pred_binary"], errors="coerce")

        for ds in datasets:
            sub = df[df["dataset"] == ds].copy()
            if sub.empty:
                continue

            n_total = len(sub)
            n_gt_nan = int(sub["binarylabel"].isna().sum())
            n_pred_nan = int(sub["pred_binary"].isna().sum())

            valid = sub.dropna(subset=["binarylabel", "pred_binary"]).copy()
            n_valid = len(valid)

            if n_valid == 0:
                weak_rows.append({
                    "model": model, "prompt": prompt, "dataset": ds,
                    "n_total": n_total, "n_valid": 0,
                    "n_gt_nan": n_gt_nan, "n_pred_nan": n_pred_nan,
                    "accuracy": pd.NA, "precision": pd.NA, "recall": pd.NA, "f1": pd.NA,
                })
                continue

            y_true = valid["binarylabel"].astype(int)
            y_pred = valid["pred_binary"].astype(int)

            weak_rows.append({
                "model": model, "prompt": prompt, "dataset": ds,
                "n_total": n_total, "n_valid": n_valid,
                "n_gt_nan": n_gt_nan, "n_pred_nan": n_pred_nan,
                "accuracy": accuracy_score(y_true, y_pred),
                "precision": precision_score(y_true, y_pred, zero_division=0),
                "recall": recall_score(y_true, y_pred, zero_division=0),
                "f1": f1_score(y_true, y_pred, zero_division=0),
            })

weak_df = pd.DataFrame(weak_rows)

# =========================
# 3) Merge + drop
# =========================
merged = weak_df.merge(clean_df, on=["model", "dataset"], how="left")

for m in ["accuracy", "precision", "recall", "f1"]:
    merged[f"{m}_drop"] = merged[m] - merged[f"clean_{m}"]

# =========================
# 4) Best prompt (model × dataset)
# =========================
best_df = (
    merged.dropna(subset=[BEST_METRIC])
    .sort_values([BEST_METRIC, "n_valid"], ascending=[False, False])
    .groupby(["model", "dataset"], as_index=False)
    .first()
)

# =========================
# 5) 예쁘게 출력 🎨
# =========================

# (A) Clean 요약 (짧게)
print("🧼 CLEAN baseline summary")
clean_pivot = (
    clean_df.pivot_table(index="model", columns="dataset", values="clean_f1", aggfunc="first")
    .reindex(models)
    .reindex(columns=datasets)
)
display(clean_pivot.style.format("{:.4f}").set_caption("Clean F1 (higher is better)"))

# (B) BEST prompt 요약표 (가장 중요 🏆)
print("\n🏆 BEST prompt per (model × modality) — based on F1 (weak only)")
best_show = best_df[[
    "model","dataset","prompt","n_valid",
    "f1","clean_f1","f1_drop",
    "recall","precision","accuracy"
]].copy()

# 보기 좋게 모델/모달리티 순서 고정
best_show["model"] = pd.Categorical(best_show["model"], categories=models, ordered=True)
best_show["dataset"] = pd.Categorical(best_show["dataset"], categories=datasets, ordered=True)
best_show = best_show.sort_values(["model","dataset"])

display(
    best_show.style
    .format({
        "f1":"{:.4f}", "clean_f1":"{:.4f}", "f1_drop":"{:+.4f}",
        "recall":"{:.4f}", "precision":"{:.4f}", "accuracy":"{:.4f}"
    })
    .background_gradient(subset=["f1"], axis=None)                 # f1 높을수록 강조
    .background_gradient(subset=["f1_drop"], axis=None)            # drop도 시각화
    .set_caption("Best prompt (weak) + clean reference + drop")
)

# (C) 모델별로 짧게: 모달리티 3줄짜리 best만 보여주기 🤖
print("\n🤖 Model-wise best prompts (compact view)")
for model in models:
    df_m = best_show[best_show["model"] == model].copy()
    if df_m.empty:
        continue

    compact = df_m.set_index("dataset")[["prompt","n_valid","f1","f1_drop","clean_f1","recall","precision","accuracy"]]
    compact = compact.reindex(datasets)

    print(f"\n✨ {model.upper()}")
    display(
        compact.style
        .format({
            "f1":"{:.4f}", "clean_f1":"{:.4f}", "f1_drop":"{:+.4f}",
            "recall":"{:.4f}", "precision":"{:.4f}", "accuracy":"{:.4f}"
        })
        .background_gradient(subset=["f1"], axis=None)
        .background_gradient(subset=["f1_drop"], axis=None)
    )
# Out:
# 🧼 CLEAN baseline summary
# <style type="text/css">
# </style>
# <table id="T_55aad">
#   <caption>Clean F1 (higher is better)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_55aad_level0_col0" class="col_heading level0 col0" >MRI</th>
#       <th id="T_55aad_level0_col1" class="col_heading level0 col1" >OCT</th>
#       <th id="T_55aad_level0_col2" class="col_heading level0 col2" >Xray</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55aad_level0_row0" class="row_heading level0 row0" >internvl</th>
#       <td id="T_55aad_row0_col0" class="data row0 col0" >0.7500</td>
#       <td id="T_55aad_row0_col1" class="data row0 col1" >0.5714</td>
#       <td id="T_55aad_row0_col2" class="data row0 col2" >0.7059</td>
#     </tr>
#     <tr>
#       <th id="T_55aad_level0_row1" class="row_heading level0 row1" >lingshu</th>
#       <td id="T_55aad_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_55aad_row1_col1" class="data row1 col1" >0.5714</td>
#       <td id="T_55aad_row1_col2" class="data row1 col2" >0.8889</td>
#     </tr>
#     <tr>
#       <th id="T_55aad_level0_row2" class="row_heading level0 row2" >medgemma</th>
#       <td id="T_55aad_row2_col0" class="data row2 col0" >0.8696</td>
#       <td id="T_55aad_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_55aad_row2_col2" class="data row2 col2" >0.8235</td>
#     </tr>
#     <tr>
#       <th id="T_55aad_level0_row3" class="row_heading level0 row3" >qwen3</th>
#       <td id="T_55aad_row3_col0" class="data row3 col0" >0.7500</td>
#       <td id="T_55aad_row3_col1" class="data row3 col1" >0.7619</td>
#       <td id="T_55aad_row3_col2" class="data row3 col2" >0.2500</td>
#     </tr>
#   </tbody>
# </table>
# 🏆 BEST prompt per (model × modality) — based on F1 (weak only)
# <style type="text/css">
# #T_c8137_row0_col4 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_c8137_row0_col6 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_c8137_row1_col4 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_c8137_row1_col6 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_c8137_row2_col4 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_c8137_row2_col6 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_c8137_row3_col4, #T_c8137_row7_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c8137_row3_col6 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_c8137_row4_col4 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_c8137_row4_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_c8137_row5_col4 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_c8137_row5_col6 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_c8137_row6_col4 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_c8137_row6_col6 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_c8137_row7_col4, #T_c8137_row10_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c8137_row8_col4 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_c8137_row8_col6 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_c8137_row9_col4 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_c8137_row9_col6 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_c8137_row10_col4 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_c8137_row11_col4 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_c8137_row11_col6 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c8137">
#   <caption>Best prompt (weak) + clean reference + drop</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8137_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_c8137_level0_col1" class="col_heading level0 col1" >dataset</th>
#       <th id="T_c8137_level0_col2" class="col_heading level0 col2" >prompt</th>
#       <th id="T_c8137_level0_col3" class="col_heading level0 col3" >n_valid</th>
#       <th id="T_c8137_level0_col4" class="col_heading level0 col4" >f1</th>
#       <th id="T_c8137_level0_col5" class="col_heading level0 col5" >clean_f1</th>
#       <th id="T_c8137_level0_col6" class="col_heading level0 col6" >f1_drop</th>
#       <th id="T_c8137_level0_col7" class="col_heading level0 col7" >recall</th>
#       <th id="T_c8137_level0_col8" class="col_heading level0 col8" >precision</th>
#       <th id="T_c8137_level0_col9" class="col_heading level0 col9" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8137_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8137_row0_col0" class="data row0 col0" >internvl</td>
#       <td id="T_c8137_row0_col1" class="data row0 col1" >MRI</td>
#       <td id="T_c8137_row0_col2" class="data row0 col2" >baseline-prompts</td>
#       <td id="T_c8137_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_c8137_row0_col4" class="data row0 col4" >0.7013</td>
#       <td id="T_c8137_row0_col5" class="data row0 col5" >0.7500</td>
#       <td id="T_c8137_row0_col6" class="data row0 col6" >-0.0487</td>
#       <td id="T_c8137_row0_col7" class="data row0 col7" >0.5400</td>
#       <td id="T_c8137_row0_col8" class="data row0 col8" >1.0000</td>
#       <td id="T_c8137_row0_col9" class="data row0 col9" >0.7700</td>
#     </tr>
#     <tr>
#       <th id="T_c8137_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8137_row1_col0" class="data row1 col0" >internvl</td>
#       <td id="T_c8137_row1_col1" class="data row1 col1" >OCT</td>
#       <td id="T_c8137_row1_col2" class="data row1 col2" >baseline-prompts</td>
#       <td id="T_c8137_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_c8137_row1_col4" class="data row1 col4" >0.1818</td>
#       <td id="T_c8137_row1_col5" class="data row1 col5" >0.5714</td>
#       <td id="T_c8137_row1_col6" class="data row1 col6" >-0.3896</td>
#       <td id="T_c8137_row1_col7" class="data row1 col7" >0.1000</td>
#       <td id="T_c8137_row1_col8" class="data row1 col8" >1.0000</td>
#       <td id="T_c8137_row1_col9" class="data row1 col9" >0.5500</td>
#     </tr>
#     <tr>
#       <th id="T_c8137_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8137_row2_col0" class="data row2 col0" >internvl</td>
#       <td id="T_c8137_row2_col1" class="data row2 col1" >Xray</td>
#       <td id="T_c8137_row2_col2" class="data row2 col2" >disease_cue-1-prompts</td>
#       <td id="T_c8137_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_c8137_row2_col4" class="data row2 col4" >0.5217</td>
#       <td id="T_c8137_row2_col5" class="data row2 col5" >0.7059</td>
#       <td id="T_c8137_row2_col6" class="data row2 col6" >-0.1841</td>
#       <td id="T_c8137_row2_col7" class="data row2 col7" >0.3600</td>
#       <td id="T_c8137_row2_col8" class="data row2 col8" >0.9474</td>
#       <td id="T_c8137_row2_col9" class="data row2 col9" >0.6700</td>
#     </tr>
#     <tr>
#       <th id="T_c8137_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8137_row3_col0" class="data row3 col0" >lingshu</td>
#       <td id="T_c8137_row3_col1" class="data row3 col1" >MRI</td>
#       <td id="T_c8137_row3_col2" class="data row3 col2" >baseline-prompts</td>
#       <td id="T_c8137_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_c8137_row3_col4" class="data row3 col4" >0.8817</td>
#       <td id="T_c8137_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_c8137_row3_col6" class="data row3 col6" >-0.1183</td>
#       <td id="T_c8137_row3_col7" class="data row3 col7" >0.8200</td>
#       <td id="T_c8137_row3_col8" class="data row3 col8" >0.9535</td>
#       <td id="T_c8137_row3_col9" class="data row3 col9" >0.8900</td>
#     </tr>
#     <tr>
#       <th id="T_c8137_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8137_row4_col0" class="data row4 col0" >lingshu</td>
#       <td id="T_c8137_row4_col1" class="data row4 col1" >OCT</td>
#       <td id="T_c8137_row4_col2" class="data row4 col2" >baseline-prompts</td>
#       <td id="T_c8137_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_c8137_row4_col4" class="data row4 col4" >0.4375</td>
#       <td id="T_c8137_row4_col5" class="data row4 col5" >0.5714</td>
#       <td id="T_c8137_row4_col6" class="data row4 col6" >-0.1339</td>
#       <td id="T_c8137_row4_col7" class="data row4 col7" >0.2800</td>
#       <td id="T_c8137_row4_col8" class="data row4 col8" >1.0000</td>
#       <td id="T_c8137_row4_col9" class="data row4 col9" >0.6400</td>
#     </tr>
#     <tr>
#       <th id="T_c8137_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8137_row5_col0" class="data row5 col0" >lingshu</td>
#       <td id="T_c8137_row5_col1" class="data row5 col1" >Xray</td>
#       <td id="T_c8137_row5_col2" class="data row5 col2" >baseline-prompts</td>
#       <td id="T_c8137_row5_col3" class="data row5 col3" >100</td>
#       <td id="T_c8137_row5_col4" class="data row5 col4" >0.7350</td>
#       <td id="T_c8137_row5_col5" class="data row5 col5" >0.8889</td>
#       <td id="T_c8137_row5_col6" class="data row5 col6" >-0.1538</td>
#       <td id="T_c8137_row5_col7" class="data row5 col7" >0.8600</td>
#       <td id="T_c8137_row5_col8" class="data row5 col8" >0.6418</td>
#       <td id="T_c8137_row5_col9" class="data row5 col9" >0.6900</td>
#     </tr>
#     <tr>
#       <th id="T_c8137_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8137_row6_col0" class="data row6 col0" >medgemma</td>
#       <td id="T_c8137_row6_col1" class="data row6 col1" >MRI</td>
#       <td id="T_c8137_row6_col2" class="data row6 col2" >disease_cue-1-prompts</td>
#       <td id="T_c8137_row6_col3" class="data row6 col3" >100</td>
#       <td id="T_c8137_row6_col4" class="data row6 col4" >0.8627</td>
#       <td id="T_c8137_row6_col5" class="data row6 col5" >0.8696</td>
#       <td id="T_c8137_row6_col6" class="data row6 col6" >-0.0068</td>
#       <td id="T_c8137_row6_col7" class="data row6 col7" >0.8800</td>
# 🤖 Model-wise best prompts (compact view)
#
# ✨ INTERNVL
# <style type="text/css">
# #T_9893c_row0_col2, #T_9893c_row0_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9893c_row1_col2, #T_9893c_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9893c_row2_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_9893c_row2_col3 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9893c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9893c_level0_col0" class="col_heading level0 col0" >prompt</th>
#       <th id="T_9893c_level0_col1" class="col_heading level0 col1" >n_valid</th>
#       <th id="T_9893c_level0_col2" class="col_heading level0 col2" >f1</th>
#       <th id="T_9893c_level0_col3" class="col_heading level0 col3" >f1_drop</th>
#       <th id="T_9893c_level0_col4" class="col_heading level0 col4" >clean_f1</th>
#       <th id="T_9893c_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_9893c_level0_col6" class="col_heading level0 col6" >precision</th>
#       <th id="T_9893c_level0_col7" class="col_heading level0 col7" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9893c_level0_row0" class="row_heading level0 row0" >MRI</th>
#       <td id="T_9893c_row0_col0" class="data row0 col0" >baseline-prompts</td>
#       <td id="T_9893c_row0_col1" class="data row0 col1" >100</td>
#       <td id="T_9893c_row0_col2" class="data row0 col2" >0.7013</td>
#       <td id="T_9893c_row0_col3" class="data row0 col3" >-0.0487</td>
#       <td id="T_9893c_row0_col4" class="data row0 col4" >0.7500</td>
#       <td id="T_9893c_row0_col5" class="data row0 col5" >0.5400</td>
#       <td id="T_9893c_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_9893c_row0_col7" class="data row0 col7" >0.7700</td>
#     </tr>
#     <tr>
#       <th id="T_9893c_level0_row1" class="row_heading level0 row1" >OCT</th>
#       <td id="T_9893c_row1_col0" class="data row1 col0" >baseline-prompts</td>
#       <td id="T_9893c_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_9893c_row1_col2" class="data row1 col2" >0.1818</td>
#       <td id="T_9893c_row1_col3" class="data row1 col3" >-0.3896</td>
#       <td id="T_9893c_row1_col4" class="data row1 col4" >0.5714</td>
#       <td id="T_9893c_row1_col5" class="data row1 col5" >0.1000</td>
#       <td id="T_9893c_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_9893c_row1_col7" class="data row1 col7" >0.5500</td>
#     </tr>
#     <tr>
#       <th id="T_9893c_level0_row2" class="row_heading level0 row2" >Xray</th>
#       <td id="T_9893c_row2_col0" class="data row2 col0" >disease_cue-1-prompts</td>
#       <td id="T_9893c_row2_col1" class="data row2 col1" >100</td>
#       <td id="T_9893c_row2_col2" class="data row2 col2" >0.5217</td>
#       <td id="T_9893c_row2_col3" class="data row2 col3" >-0.1841</td>
#       <td id="T_9893c_row2_col4" class="data row2 col4" >0.7059</td>
#       <td id="T_9893c_row2_col5" class="data row2 col5" >0.3600</td>
#       <td id="T_9893c_row2_col6" class="data row2 col6" >0.9474</td>
#       <td id="T_9893c_row2_col7" class="data row2 col7" >0.6700</td>
#     </tr>
#   </tbody>
# </table>
# ✨ LINGSHU
# <style type="text/css">
# #T_13cca_row0_col2, #T_13cca_row0_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_13cca_row1_col2, #T_13cca_row2_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_13cca_row1_col3 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_13cca_row2_col2 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_13cca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13cca_level0_col0" class="col_heading level0 col0" >prompt</th>
#       <th id="T_13cca_level0_col1" class="col_heading level0 col1" >n_valid</th>
#       <th id="T_13cca_level0_col2" class="col_heading level0 col2" >f1</th>
#       <th id="T_13cca_level0_col3" class="col_heading level0 col3" >f1_drop</th>
#       <th id="T_13cca_level0_col4" class="col_heading level0 col4" >clean_f1</th>
#       <th id="T_13cca_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_13cca_level0_col6" class="col_heading level0 col6" >precision</th>
#       <th id="T_13cca_level0_col7" class="col_heading level0 col7" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13cca_level0_row0" class="row_heading level0 row0" >MRI</th>
#       <td id="T_13cca_row0_col0" class="data row0 col0" >baseline-prompts</td>
#       <td id="T_13cca_row0_col1" class="data row0 col1" >100</td>
#       <td id="T_13cca_row0_col2" class="data row0 col2" >0.8817</td>
#       <td id="T_13cca_row0_col3" class="data row0 col3" >-0.1183</td>
#       <td id="T_13cca_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_13cca_row0_col5" class="data row0 col5" >0.8200</td>
#       <td id="T_13cca_row0_col6" class="data row0 col6" >0.9535</td>
#       <td id="T_13cca_row0_col7" class="data row0 col7" >0.8900</td>
#     </tr>
#     <tr>
#       <th id="T_13cca_level0_row1" class="row_heading level0 row1" >OCT</th>
#       <td id="T_13cca_row1_col0" class="data row1 col0" >baseline-prompts</td>
#       <td id="T_13cca_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_13cca_row1_col2" class="data row1 col2" >0.4375</td>
#       <td id="T_13cca_row1_col3" class="data row1 col3" >-0.1339</td>
#       <td id="T_13cca_row1_col4" class="data row1 col4" >0.5714</td>
#       <td id="T_13cca_row1_col5" class="data row1 col5" >0.2800</td>
#       <td id="T_13cca_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_13cca_row1_col7" class="data row1 col7" >0.6400</td>
#     </tr>
#     <tr>
#       <th id="T_13cca_level0_row2" class="row_heading level0 row2" >Xray</th>
#       <td id="T_13cca_row2_col0" class="data row2 col0" >baseline-prompts</td>
#       <td id="T_13cca_row2_col1" class="data row2 col1" >100</td>
#       <td id="T_13cca_row2_col2" class="data row2 col2" >0.7350</td>
#       <td id="T_13cca_row2_col3" class="data row2 col3" >-0.1538</td>
#       <td id="T_13cca_row2_col4" class="data row2 col4" >0.8889</td>
#       <td id="T_13cca_row2_col5" class="data row2 col5" >0.8600</td>
#       <td id="T_13cca_row2_col6" class="data row2 col6" >0.6418</td>
#       <td id="T_13cca_row2_col7" class="data row2 col7" >0.6900</td>
#     </tr>
#   </tbody>
# </table>
# ✨ MEDGEMMA
# <style type="text/css">
# #T_820e8_row0_col2, #T_820e8_row1_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_820e8_row0_col3 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_820e8_row1_col2, #T_820e8_row2_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_820e8_row2_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# </style>
# <table id="T_820e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_820e8_level0_col0" class="col_heading level0 col0" >prompt</th>
#       <th id="T_820e8_level0_col1" class="col_heading level0 col1" >n_valid</th>
#       <th id="T_820e8_level0_col2" class="col_heading level0 col2" >f1</th>
#       <th id="T_820e8_level0_col3" class="col_heading level0 col3" >f1_drop</th>
#       <th id="T_820e8_level0_col4" class="col_heading level0 col4" >clean_f1</th>
#       <th id="T_820e8_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_820e8_level0_col6" class="col_heading level0 col6" >precision</th>
#       <th id="T_820e8_level0_col7" class="col_heading level0 col7" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_820e8_level0_row0" class="row_heading level0 row0" >MRI</th>
#       <td id="T_820e8_row0_col0" class="data row0 col0" >disease_cue-1-prompts</td>
#       <td id="T_820e8_row0_col1" class="data row0 col1" >100</td>
#       <td id="T_820e8_row0_col2" class="data row0 col2" >0.8627</td>
#       <td id="T_820e8_row0_col3" class="data row0 col3" >-0.0068</td>
#       <td id="T_820e8_row0_col4" class="data row0 col4" >0.8696</td>
#       <td id="T_820e8_row0_col5" class="data row0 col5" >0.8800</td>
#       <td id="T_820e8_row0_col6" class="data row0 col6" >0.8462</td>
#       <td id="T_820e8_row0_col7" class="data row0 col7" >0.8600</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row1" class="row_heading level0 row1" >OCT</th>
#       <td id="T_820e8_row1_col0" class="data row1 col0" >disease_cue-1-prompts</td>
#       <td id="T_820e8_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_820e8_row1_col2" class="data row1 col2" >0.0392</td>
#       <td id="T_820e8_row1_col3" class="data row1 col3" >+0.0392</td>
#       <td id="T_820e8_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_820e8_row1_col5" class="data row1 col5" >0.0200</td>
#       <td id="T_820e8_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_820e8_row1_col7" class="data row1 col7" >0.5100</td>
#     </tr>
#     <tr>
#       <th id="T_820e8_level0_row2" class="row_heading level0 row2" >Xray</th>
#       <td id="T_820e8_row2_col0" class="data row2 col0" >disease_cue-1-prompts</td>
#       <td id="T_820e8_row2_col1" class="data row2 col1" >100</td>
#       <td id="T_820e8_row2_col2" class="data row2 col2" >0.3871</td>
#       <td id="T_820e8_row2_col3" class="data row2 col3" >-0.4364</td>
#       <td id="T_820e8_row2_col4" class="data row2 col4" >0.8235</td>
#       <td id="T_820e8_row2_col5" class="data row2 col5" >0.2400</td>
#       <td id="T_820e8_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_820e8_row2_col7" class="data row2 col7" >0.6200</td>
#     </tr>
#   </tbody>
# </table>
# ✨ QWEN3
# <style type="text/css">
# #T_9db67_row0_col2, #T_9db67_row2_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9db67_row0_col3 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_9db67_row1_col2, #T_9db67_row1_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9db67_row2_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# </style>
# <table id="T_9db67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9db67_level0_col0" class="col_heading level0 col0" >prompt</th>
#       <th id="T_9db67_level0_col1" class="col_heading level0 col1" >n_valid</th>
#       <th id="T_9db67_level0_col2" class="col_heading level0 col2" >f1</th>
#       <th id="T_9db67_level0_col3" class="col_heading level0 col3" >f1_drop</th>
#       <th id="T_9db67_level0_col4" class="col_heading level0 col4" >clean_f1</th>
#       <th id="T_9db67_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_9db67_level0_col6" class="col_heading level0 col6" >precision</th>
#       <th id="T_9db67_level0_col7" class="col_heading level0 col7" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9db67_level0_row0" class="row_heading level0 row0" >MRI</th>
#       <td id="T_9db67_row0_col0" class="data row0 col0" >disease_cue-1-prompts</td>
#       <td id="T_9db67_row0_col1" class="data row0 col1" >100</td>
#       <td id="T_9db67_row0_col2" class="data row0 col2" >0.5294</td>
#       <td id="T_9db67_row0_col3" class="data row0 col3" >-0.2206</td>
#       <td id="T_9db67_row0_col4" class="data row0 col4" >0.7500</td>
#       <td id="T_9db67_row0_col5" class="data row0 col5" >0.3600</td>
#       <td id="T_9db67_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_9db67_row0_col7" class="data row0 col7" >0.6800</td>
#     </tr>
#     <tr>
#       <th id="T_9db67_level0_row1" class="row_heading level0 row1" >OCT</th>
#       <td id="T_9db67_row1_col0" class="data row1 col0" >baseline-prompts</td>
#       <td id="T_9db67_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_9db67_row1_col2" class="data row1 col2" >0.2069</td>
#       <td id="T_9db67_row1_col3" class="data row1 col3" >-0.5550</td>
#       <td id="T_9db67_row1_col4" class="data row1 col4" >0.7619</td>
#       <td id="T_9db67_row1_col5" class="data row1 col5" >0.1200</td>
#       <td id="T_9db67_row1_col6" class="data row1 col6" >0.7500</td>
#       <td id="T_9db67_row1_col7" class="data row1 col7" >0.5400</td>
#     </tr>
#     <tr>
#       <th id="T_9db67_level0_row2" class="row_heading level0 row2" >Xray</th>
#       <td id="T_9db67_row2_col0" class="data row2 col0" >disease_cue-1-prompts</td>
#       <td id="T_9db67_row2_col1" class="data row2 col1" >100</td>
#       <td id="T_9db67_row2_col2" class="data row2 col2" >0.2456</td>
#       <td id="T_9db67_row2_col3" class="data row2 col3" >-0.0044</td>
#       <td id="T_9db67_row2_col4" class="data row2 col4" >0.2500</td>
#       <td id="T_9db67_row2_col5" class="data row2 col5" >0.1400</td>
#       <td id="T_9db67_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_9db67_row2_col7" class="data row2 col7" >0.5700</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 3) Strong image performance

# %%
import pandas as pd
from pathlib import Path

models = ["internvl", "lingshu", "medgemma", "qwen3"]

datasets = ["MRI", "OCT", "Xray"]

rows = []

for model in models:
    for prompt in prompts:
        file = f"{model}_{prompt}.csv"
        if not Path(file).exists():
            continue

        df = pd.read_csv(file)

        # 🔴 strong만
        df = df[df["severity"] == "strong"].copy()
        if df.empty:
            continue

        # dataset 표기 통일
        df["dataset"] = df["dataset"].replace({"XRAY": "Xray", "XRay": "Xray"})

        for ds in datasets:
            sub = df[df["dataset"] == ds].copy()
            if sub.empty:
                continue

            n_total = len(sub)
            n_distorted = (sub["model_pred"] == "distorted").sum()

            rows.append({
                "model": model,
                "prompt": prompt,
                "dataset": ds,
                "n_total": n_total,
                "n_distorted": int(n_distorted),
                "distorted_ratio": n_distorted / n_total,
            })

strong_df = pd.DataFrame(rows)
#print(strong_df.round(4))

# %%
from IPython.display import display

for prompt in strong_df["prompt"].unique():
    print(f"\n🧨 STRONG — PROMPT: {prompt}")

    tbl = (
        strong_df[strong_df["prompt"] == prompt]
        .pivot_table(
            index="model",
            columns="dataset",
            values="distorted_ratio",
            aggfunc="first",
        )
        .reindex(index=models, columns=datasets)
    )

    display(
        tbl.style
        .format("{:.2%}")
        .background_gradient(axis=None)
        .set_caption("Distorted output ratio (severity = strong)")
    )
# Out:
# 🧨 STRONG — PROMPT: baseline-prompts
# <style type="text/css">
# #T_126d6_row0_col0, #T_126d6_row3_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_126d6_row0_col1 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_126d6_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_126d6_row1_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_126d6_row1_col1, #T_126d6_row3_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_126d6_row1_col2 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_126d6_row2_col0, #T_126d6_row2_col2, #T_126d6_row3_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_126d6_row2_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_126d6">
#   <caption>Distorted output ratio (severity = strong)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_126d6_level0_col0" class="col_heading level0 col0" >MRI</th>
#       <th id="T_126d6_level0_col1" class="col_heading level0 col1" >OCT</th>
#       <th id="T_126d6_level0_col2" class="col_heading level0 col2" >Xray</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_126d6_level0_row0" class="row_heading level0 row0" >internvl</th>
#       <td id="T_126d6_row0_col0" class="data row0 col0" >14.00%</td>
#       <td id="T_126d6_row0_col1" class="data row0 col1" >8.00%</td>
#       <td id="T_126d6_row0_col2" class="data row0 col2" >44.00%</td>
#     </tr>
#     <tr>
#       <th id="T_126d6_level0_row1" class="row_heading level0 row1" >lingshu</th>
#       <td id="T_126d6_row1_col0" class="data row1 col0" >11.00%</td>
#       <td id="T_126d6_row1_col1" class="data row1 col1" >2.00%</td>
#       <td id="T_126d6_row1_col2" class="data row1 col2" >35.00%</td>
#     </tr>
#     <tr>
#       <th id="T_126d6_level0_row2" class="row_heading level0 row2" >medgemma</th>
#       <td id="T_126d6_row2_col0" class="data row2 col0" >1.00%</td>
#       <td id="T_126d6_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_126d6_row2_col2" class="data row2 col2" >1.00%</td>
#     </tr>
#     <tr>
#       <th id="T_126d6_level0_row3" class="row_heading level0 row3" >qwen3</th>
#       <td id="T_126d6_row3_col0" class="data row3 col0" >2.00%</td>
#       <td id="T_126d6_row3_col1" class="data row3 col1" >1.00%</td>
#       <td id="T_126d6_row3_col2" class="data row3 col2" >14.00%</td>
#     </tr>
#   </tbody>
# </table>
# 🧨 STRONG — PROMPT: disease-cue-reason-1-prompts
# <style type="text/css">
# #T_30f49_row0_col0, #T_30f49_row0_col1, #T_30f49_row0_col2, #T_30f49_row2_col0, #T_30f49_row2_col1, #T_30f49_row2_col2, #T_30f49_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_30f49_row1_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_30f49_row1_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_30f49_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_30f49_row3_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_30f49_row3_col2 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# </style>
# <table id="T_30f49">
#   <caption>Distorted output ratio (severity = strong)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_30f49_level0_col0" class="col_heading level0 col0" >MRI</th>
#       <th id="T_30f49_level0_col1" class="col_heading level0 col1" >OCT</th>
#       <th id="T_30f49_level0_col2" class="col_heading level0 col2" >Xray</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30f49_level0_row0" class="row_heading level0 row0" >internvl</th>
#       <td id="T_30f49_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_30f49_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_30f49_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_30f49_level0_row1" class="row_heading level0 row1" >lingshu</th>
#       <td id="T_30f49_row1_col0" class="data row1 col0" >16.00%</td>
#       <td id="T_30f49_row1_col1" class="data row1 col1" >1.00%</td>
#       <td id="T_30f49_row1_col2" class="data row1 col2" >43.00%</td>
#     </tr>
#     <tr>
#       <th id="T_30f49_level0_row2" class="row_heading level0 row2" >medgemma</th>
#       <td id="T_30f49_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_30f49_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_30f49_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_30f49_level0_row3" class="row_heading level0 row3" >qwen3</th>
#       <td id="T_30f49_row3_col0" class="data row3 col0" >2.00%</td>
#       <td id="T_30f49_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_30f49_row3_col2" class="data row3 col2" >6.00%</td>
#     </tr>
#   </tbody>
# </table>
# 🧨 STRONG — PROMPT: disease_cue-1-prompts
# <style type="text/css">
# #T_9c8e9_row0_col0, #T_9c8e9_row0_col2, #T_9c8e9_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9c8e9_row0_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_9c8e9_row1_col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_9c8e9_row1_col1, #T_9c8e9_row2_col0, #T_9c8e9_row2_col1, #T_9c8e9_row2_col2, #T_9c8e9_row3_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_9c8e9_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9c8e9_row3_col2 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# </style>
# <table id="T_9c8e9">
#   <caption>Distorted output ratio (severity = strong)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_9c8e9_level0_col0" class="col_heading level0 col0" >MRI</th>
#       <th id="T_9c8e9_level0_col1" class="col_heading level0 col1" >OCT</th>
#       <th id="T_9c8e9_level0_col2" class="col_heading level0 col2" >Xray</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c8e9_level0_row0" class="row_heading level0 row0" >internvl</th>
#       <td id="T_9c8e9_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_9c8e9_row0_col1" class="data row0 col1" >2.00%</td>
#       <td id="T_9c8e9_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9c8e9_level0_row1" class="row_heading level0 row1" >lingshu</th>
#       <td id="T_9c8e9_row1_col0" class="data row1 col0" >18.00%</td>
#       <td id="T_9c8e9_row1_col1" class="data row1 col1" >3.00%</td>
#       <td id="T_9c8e9_row1_col2" class="data row1 col2" >41.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9c8e9_level0_row2" class="row_heading level0 row2" >medgemma</th>
#       <td id="T_9c8e9_row2_col0" class="data row2 col0" >3.00%</td>
#       <td id="T_9c8e9_row2_col1" class="data row2 col1" >3.00%</td>
#       <td id="T_9c8e9_row2_col2" class="data row2 col2" >3.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9c8e9_level0_row3" class="row_heading level0 row3" >qwen3</th>
#       <td id="T_9c8e9_row3_col0" class="data row3 col0" >3.00%</td>
#       <td id="T_9c8e9_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_9c8e9_row3_col2" class="data row3 col2" >7.00%</td>
#     </tr>
#   </tbody>
# </table>
# 🧨 STRONG — PROMPT: artefact-disease-cue-2-prompts
# <style type="text/css">
# #T_d817c_row0_col0, #T_d817c_row3_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_d817c_row0_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_d817c_row0_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d817c_row1_col0 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_d817c_row1_col1, #T_d817c_row2_col0, #T_d817c_row2_col1, #T_d817c_row2_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_d817c_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d817c_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_d817c_row3_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# </style>
# <table id="T_d817c">
#   <caption>Distorted output ratio (severity = strong)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_d817c_level0_col0" class="col_heading level0 col0" >MRI</th>
#       <th id="T_d817c_level0_col1" class="col_heading level0 col1" >OCT</th>
#       <th id="T_d817c_level0_col2" class="col_heading level0 col2" >Xray</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d817c_level0_row0" class="row_heading level0 row0" >internvl</th>
#       <td id="T_d817c_row0_col0" class="data row0 col0" >2.00%</td>
#       <td id="T_d817c_row0_col1" class="data row0 col1" >5.00%</td>
#       <td id="T_d817c_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_d817c_level0_row1" class="row_heading level0 row1" >lingshu</th>
#       <td id="T_d817c_row1_col0" class="data row1 col0" >17.00%</td>
#       <td id="T_d817c_row1_col1" class="data row1 col1" >4.00%</td>
#       <td id="T_d817c_row1_col2" class="data row1 col2" >52.00%</td>
#     </tr>
#     <tr>
#       <th id="T_d817c_level0_row2" class="row_heading level0 row2" >medgemma</th>
#       <td id="T_d817c_row2_col0" class="data row2 col0" >4.00%</td>
#       <td id="T_d817c_row2_col1" class="data row2 col1" >4.00%</td>
#       <td id="T_d817c_row2_col2" class="data row2 col2" >4.00%</td>
#     </tr>
#     <tr>
#       <th id="T_d817c_level0_row3" class="row_heading level0 row3" >qwen3</th>
#       <td id="T_d817c_row3_col0" class="data row3 col0" >3.00%</td>
#       <td id="T_d817c_row3_col1" class="data row3 col1" >2.00%</td>
#       <td id="T_d817c_row3_col2" class="data row3 col2" >10.00%</td>
#     </tr>
#   </tbody>
# </table>
# 🧨 STRONG — PROMPT: artefact_disease_cue-1-prompts
# <style type="text/css">
# #T_5b349_row0_col0, #T_5b349_row0_col2, #T_5b349_row3_col0, #T_5b349_row3_col1, #T_5b349_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5b349_row0_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_5b349_row1_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_5b349_row1_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_5b349_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5b349_row2_col0, #T_5b349_row2_col1, #T_5b349_row2_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# </style>
# <table id="T_5b349">
#   <caption>Distorted output ratio (severity = strong)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_5b349_level0_col0" class="col_heading level0 col0" >MRI</th>
#       <th id="T_5b349_level0_col1" class="col_heading level0 col1" >OCT</th>
#       <th id="T_5b349_level0_col2" class="col_heading level0 col2" >Xray</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b349_level0_row0" class="row_heading level0 row0" >internvl</th>
#       <td id="T_5b349_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_5b349_row0_col1" class="data row0 col1" >3.00%</td>
#       <td id="T_5b349_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5b349_level0_row1" class="row_heading level0 row1" >lingshu</th>
#       <td id="T_5b349_row1_col0" class="data row1 col0" >8.00%</td>
#       <td id="T_5b349_row1_col1" class="data row1 col1" >1.00%</td>
#       <td id="T_5b349_row1_col2" class="data row1 col2" >41.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5b349_level0_row2" class="row_heading level0 row2" >medgemma</th>
#       <td id="T_5b349_row2_col0" class="data row2 col0" >2.00%</td>
#       <td id="T_5b349_row2_col1" class="data row2 col1" >2.00%</td>
#       <td id="T_5b349_row2_col2" class="data row2 col2" >2.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5b349_level0_row3" class="row_heading level0 row3" >qwen3</th>
#       <td id="T_5b349_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_5b349_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_5b349_row3_col2" class="data row3 col2" >0.00%</td>
#     </tr>
#   </tbody>
# </table>
# 🧨 STRONG — PROMPT: artefact-disease-cue-reason-1-prompts
# <style type="text/css">
# #T_5ceb2_row0_col0, #T_5ceb2_row0_col1, #T_5ceb2_row0_col2, #T_5ceb2_row2_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5ceb2_row1_col0 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_5ceb2_row1_col1, #T_5ceb2_row3_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5ceb2_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5ceb2_row2_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_5ceb2_row2_col2, #T_5ceb2_row3_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_5ceb2_row3_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# </style>
# <table id="T_5ceb2">
#   <caption>Distorted output ratio (severity = strong)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_5ceb2_level0_col0" class="col_heading level0 col0" >MRI</th>
#       <th id="T_5ceb2_level0_col1" class="col_heading level0 col1" >OCT</th>
#       <th id="T_5ceb2_level0_col2" class="col_heading level0 col2" >Xray</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ceb2_level0_row0" class="row_heading level0 row0" >internvl</th>
#       <td id="T_5ceb2_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_5ceb2_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_5ceb2_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5ceb2_level0_row1" class="row_heading level0 row1" >lingshu</th>
#       <td id="T_5ceb2_row1_col0" class="data row1 col0" >26.00%</td>
#       <td id="T_5ceb2_row1_col1" class="data row1 col1" >3.00%</td>
#       <td id="T_5ceb2_row1_col2" class="data row1 col2" >53.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5ceb2_level0_row2" class="row_heading level0 row2" >medgemma</th>
#       <td id="T_5ceb2_row2_col0" class="data row2 col0" >2.00%</td>
#       <td id="T_5ceb2_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_5ceb2_row2_col2" class="data row2 col2" >1.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5ceb2_level0_row3" class="row_heading level0 row3" >qwen3</th>
#       <td id="T_5ceb2_row3_col0" class="data row3 col0" >3.00%</td>
#       <td id="T_5ceb2_row3_col1" class="data row3 col1" >1.00%</td>
#       <td id="T_5ceb2_row3_col2" class="data row3 col2" >7.00%</td>
#     </tr>
#   </tbody>
# </table>
